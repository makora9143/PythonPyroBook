# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.api as sm
from scipy import stats

import torch
import pyro
from pyro import distributions as dist
from pyro.infer.mcmc import NUTS, MCMC
from pyro.infer.abstract_infer import EmpiricalMarginal, TracePredictive

# %%
data = pd.read_csv("input/data-conc-2.txt")

# %%
data
# Out:
#     PersonID  Time1  Time2  Time4  Time8  Time12  Time24
# 0          1    2.4    5.0    7.5   11.9    12.5    12.7
# 1          2    1.4    3.9    4.4    7.7     6.4     8.3
# 2          3    5.2    9.4   19.4   20.2    22.7    24.9
# 3          4    6.7   12.6   19.1   23.4    25.8    26.1
# 4          5    0.3    4.7    7.0   10.2    12.9    14.8
# 5          6    6.3    3.8   11.8    9.2    13.9    18.2
# 6          7    3.0    4.2    8.8   15.4    10.7    16.2
# 7          8    6.2    6.8    9.4   11.3    12.4    14.7
# 8          9   14.4   17.0   22.7   29.8    33.0    32.2
# 9         10    7.7   10.0   14.8   15.3    18.0    18.7
# 10        11    8.8   11.3   13.3   19.2    17.4    21.8
# 11        12    6.8   12.6   13.4   14.9    16.8    16.0
# 12        13    0.7    4.6    5.1    9.9    11.4    11.2
# 13        14    5.8    9.4   14.3   23.1    22.9    25.2
# 14        15    1.8    7.9   13.2   15.6    16.5    15.9
# ...

# %%
fig, axes = plt.subplots(4, 4, figsize=(16, 12))
for i in range(4):
    for j in range(4):
        axes[i, j].plot([1, 2, 4, 8, 12, 24], data.loc[i*4+j].values[1:])
        axes[i, j].plot([1, 2, 4, 8, 12, 24], data.loc[i*4+j].values[1:], 'bo')

# %%
sns.distplot(data.Time24)

# %%
data.values[:, 1:].shape
# Out:
# (16, 6)

# %%
Time = torch.tensor([1, 2, 4, 8, 12, 24]).float()
Y = torch.tensor(data.values[:, 1:]).float()

# %% [markdown]
# ## モデル式
#
# $Y[n, t] \sim Normal(a[n]\{ 1 - \exp (-b[n]Time[t])\}, \sigma_Y)$
#
# $\log (a[n]) \sim Normal(a_{g}, \sigma_a)$
#
# $\log (b[n]) \sim Normal(b_{g}, \sigma_b)$

# %%
def model(Time, Y):
    a_g = pyro.sample("a_g", dist.Normal(0, 100))
    b_g = pyro.sample("b_g", dist.Normal(0, 100))
    
    sigma_a = pyro.sample("sigma_a", dist.Uniform(0, 1000))
    sigma_b = pyro.sample("sigma_b", dist.Uniform(0, 1000))
    sigma_y = pyro.sample("sigma_y", dist.Uniform(0, 1000))
    
    with pyro.plate("data", Y.size(0)), pyro.plate("time", Y.size(1)):
        log_a_n = pyro.sample("log_a_n", dist.Normal(a_g, sigma_a))
        log_b_n = pyro.sample("log_b_n", dist.Normal(b_g, sigma_b))
        pyro.sample("obs", dist.Normal(torch.exp(log_a_n).reshape(-1, 1) * (1 - torch.exp(torch.matmul(-torch.exp(log_b_n).reshape(-1, 1), Time.reshape(1, -1)))), sigma_y),
                    obs=Y.reshape(6, -1))

# %%
tmp = model(Time, Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-611fa936fd50> in <module>
# ----> 1 tmp = model(Time, Y)
#
# <ipython-input-112-cf990ad8b11c> in model(Time, Y)
#      11         log_b_n = pyro.sample("log_b_n", dist.Normal(b_g, sigma_b))
#      12         pyro.sample("obs", dist.Normal(torch.exp(log_a_n).reshape(-1, 1) * (1 - torch.exp(torch.matmul(-torch.exp(log_b_n).reshape(-1, 1), Time.reshape(1, -1)))), sigma_y),
# ---> 13                     obs=Y.reshape(6, -1))
#
# ~/.pyenv/versions/miniconda3-latest/lib/python3.7/site-packages/pyro/primitives.py in sample(name, fn, *args, **kwargs)
#      96             msg["is_observed"] = True
#      97         # apply the stack and return its return value
# ---> 98         apply_stack(msg)
#      99         return msg["value"]
#     100
#
# ...

# %%
kernel = NUTS(model, adapt_step_size=True, jit_compile=True, ignore_jit_warnings=True)
posterior = MCMC(kernel, num_samples=10, num_chains=4, warmup_steps=10).run(Time, Y)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-99-bf1ec25542da> in <module>
#       1 kernel = NUTS(model, adapt_step_size=True, jit_compile=True, ignore_jit_warnings=True)
# ----> 2 posterior = MCMC(kernel, num_samples=10, num_chains=4, warmup_steps=10).run(Time, Y)
#
# ~/.pyenv/versions/miniconda3-latest/lib/python3.7/site-packages/pyro/infer/abstract_infer.py in run(self, *args, **kwargs)
#     221         self._reset()
#     222         with poutine.block():
# --> 223             for i, vals in enumerate(self._traces(*args, **kwargs)):
#     224                 if len(vals) == 2:
#     225                     chain_id = 0
#
# ~/.pyenv/versions/miniconda3-latest/lib/python3.7/site-packages/pyro/infer/mcmc/mcmc.py in _traces(self, *args, **kwargs)
#     273
#     274     def _traces(self, *args, **kwargs):
# ...
